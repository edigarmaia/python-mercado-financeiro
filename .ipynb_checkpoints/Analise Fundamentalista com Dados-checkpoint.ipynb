# %% [markdown]
# ## Projeto Renner: Como proteger a receita das empresas com a abertura de novas lojas

# %%
# !pip install mplcyberpunk

# %%
import pandas as pd
import matplotlib.pyplot as plt
import mplcyberpunk

plt.style.use('cyberpunk')

# %% [markdown]
# ### Coleta e tratamento de dados

# %% [markdown]
# #### Passo 1 - Ler e tratar os dados de lojas atuais

# %% [markdown]
# #### Lendo uma aba da planilha

# %%
aba_planilha = 'Lista de Lojas | Stores List'

# %% [markdown]
# #### Escolhendo as colunas da tabela

# %%
planilha_renner = pd.read_excel('lojas_renner.xlsx', sheet_name = aba_planilha, skiprows = 5,
                               usecols= ['Business', 'Country', 'UF', 'State', 'City', 'Opening date',
                                        'Shopping Mall / Street'])

planilha_renner
# Out:
#            Business         Opening date  Country   UF           State  \
# 0            Renner  2023-12-21 00:00:00  Uruguay   UY         Uruguay
# 1            Youcom  2023-11-30 00:00:00   Brazil   BA           Bahia
# 2            Renner  2023-11-30 00:00:00   Brazil   ES  Espírito Santo
# 3            Youcom  2023-11-30 00:00:00   Brazil   BA           Bahia
# 4            Youcom  2023-11-23 00:00:00   Brazil   SP       São Paulo
# ..              ...                  ...      ...  ...             ...
# 775  Rio de Janeiro                   41        4   57             NaN
# 776       São Paulo                  119       48  209             NaN
# 777         Uruguay                   11        0   11             NaN
# 778       Argentina                    4        0    4             NaN
# 779           Total                  424      124  671             NaN
#
#                  City Shopping Mall / Street
# 0           Maldonado          Shopping Mall
# 1            Salvador          Shopping Mall
# 2             Aracruz          Shopping Mall
# 3    Lauro de Freitas          Shopping Mall
# 4           São Paulo          Shopping Mall
# ..                ...                    ...
# 775               NaN                    NaN
# 776               NaN                    NaN
# 777               NaN                    NaN
# 778               NaN                    NaN
# 779               NaN                    NaN
#
# [780 rows x 7 columns]

# %% [markdown]
# #### Removendo os dados NaN

# %%
planilha_renner = planilha_renner.dropna()

planilha_renner
# Out:
#     Business         Opening date  Country  UF              State  \
# 0     Renner  2023-12-21 00:00:00  Uruguay  UY            Uruguay
# 1     Youcom  2023-11-30 00:00:00   Brazil  BA              Bahia
# 2     Renner  2023-11-30 00:00:00   Brazil  ES     Espírito Santo
# 3     Youcom  2023-11-30 00:00:00   Brazil  BA              Bahia
# 4     Youcom  2023-11-23 00:00:00   Brazil  SP          São Paulo
# ..       ...                  ...      ...  ..                ...
# 735   Renner  1980-09-01 00:00:00   Brazil  RS  Rio Grande do Sul
# 736   Renner  1977-11-01 00:00:00   Brazil  RS  Rio Grande do Sul
# 737   Renner  1976-04-10 00:00:00   Brazil  RS  Rio Grande do Sul
# 738   Renner  1970-12-04 00:00:00   Brazil  RS  Rio Grande do Sul
# 739   Renner  1967-06-01 00:00:00   Brazil  RS  Rio Grande do Sul
#
#                  City Shopping Mall / Street
# 0           Maldonado          Shopping Mall
# 1            Salvador          Shopping Mall
# 2             Aracruz          Shopping Mall
# 3    Lauro de Freitas          Shopping Mall
# 4           São Paulo          Shopping Mall
# ..                ...                    ...
# 735       Santa Maria                 Street
# 736      Porto Alegre                 Street
# 737            Canoas          Shopping Mall
# 738      Porto Alegre          Shopping Mall
# 739           Pelotas                 Street
#
# [740 rows x 7 columns]

# %% [markdown]
# #### Filtrando dados da tabela

# %%
planilha_renner = planilha_renner[(planilha_renner['Business'] == 'Renner') &
                                  (planilha_renner['Country'] == 'Brazil')] 

planilha_renner
# Out:
#     Business         Opening date Country  UF              State  \
# 2     Renner  2023-11-30 00:00:00  Brazil  ES     Espírito Santo
# 8     Renner  2023-11-09 00:00:00  Brazil  SP          São Paulo
# 10    Renner  2023-10-27 00:00:00  Brazil  RS  Rio Grande do Sul
# 11    Renner  2023-10-17 00:00:00  Brazil  MG       Minas Gerais
# 12    Renner  2023-10-11 00:00:00  Brazil  SC     Santa Catarina
# ..       ...                  ...     ...  ..                ...
# 735   Renner  1980-09-01 00:00:00  Brazil  RS  Rio Grande do Sul
# 736   Renner  1977-11-01 00:00:00  Brazil  RS  Rio Grande do Sul
# 737   Renner  1976-04-10 00:00:00  Brazil  RS  Rio Grande do Sul
# 738   Renner  1970-12-04 00:00:00  Brazil  RS  Rio Grande do Sul
# 739   Renner  1967-06-01 00:00:00  Brazil  RS  Rio Grande do Sul
#
#              City Shopping Mall / Street
# 2         Aracruz          Shopping Mall
# 8       São Paulo          Shopping Mall
# 10     Montenegro                 Street
# 11      Ituiutaba          Shopping Mall
# 12        Videira          Shopping Mall
# ..            ...                    ...
# 735   Santa Maria                 Street
# 736  Porto Alegre                 Street
# 737        Canoas          Shopping Mall
# 738  Porto Alegre          Shopping Mall
# 739       Pelotas                 Street
#
# [433 rows x 7 columns]

# %% [markdown]
# #### Convertendo para data sem a hora

# %%
planilha_renner['Opening date'] = pd.to_datetime(planilha_renner['Opening date']).dt.date

planilha_renner
# Out:
# C:\Users\home\AppData\Local\Temp\ipykernel_8276\439265232.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   planilha_renner['Opening date'] = pd.to_datetime(planilha_renner['Opening date']).dt.date
#     Business Opening date Country  UF              State          City  \
# 2     Renner   2023-11-30  Brazil  ES     Espírito Santo       Aracruz
# 8     Renner   2023-11-09  Brazil  SP          São Paulo     São Paulo
# 10    Renner   2023-10-27  Brazil  RS  Rio Grande do Sul    Montenegro
# 11    Renner   2023-10-17  Brazil  MG       Minas Gerais     Ituiutaba
# 12    Renner   2023-10-11  Brazil  SC     Santa Catarina       Videira
# ..       ...          ...     ...  ..                ...           ...
# 735   Renner   1980-09-01  Brazil  RS  Rio Grande do Sul   Santa Maria
# 736   Renner   1977-11-01  Brazil  RS  Rio Grande do Sul  Porto Alegre
# 737   Renner   1976-04-10  Brazil  RS  Rio Grande do Sul        Canoas
# 738   Renner   1970-12-04  Brazil  RS  Rio Grande do Sul  Porto Alegre
# 739   Renner   1967-06-01  Brazil  RS  Rio Grande do Sul       Pelotas
#
#     Shopping Mall / Street
# 2            Shopping Mall
# 8            Shopping Mall
# 10                  Street
# 11           Shopping Mall
# 12           Shopping Mall
# ..                     ...
# 735                 Street
# 736                 Street
# 737          Shopping Mall
# 738          Shopping Mall
# 739                 Street
#
# [433 rows x 7 columns]

# %% [markdown]
# ### Passo 2 - Ler e tratar dados dos munícipios brasileiros
#
# Vamos no SIDRA, do IBGE.
#
# https://sidra.ibge.gov.br/pesquisa/censo-demografico/demografico-2022/primeiros-resultados-populacao-e-domicilios
#
# <br>
#
# https://sidra.ibge.gov.br/pesquisa/pib-munic/tabelas

# %%
pib_municipios = pd.read_excel('pib_municipios.xlsx')

pop_municipios = pd.read_excel('populacao_municipios.xlsx')

pop_municipios
# Out:
#                             City      pop
# 0     Alta Floresta D'Oeste (RO)    21494
# 1                 Ariquemes (RO)    96833
# 2                    Cabixi (RO)     5351
# 3                    Cacoal (RO)    86887
# 4                Cerejeiras (RO)    15890
# ...                          ...      ...
# 5565             Vianópolis (GO)    14956
# 5566         Vicentinópolis (GO)     8768
# 5567               Vila Boa (GO)     4215
# 5568          Vila Propício (GO)     5815
# 5569               Brasília (DF)  2817381
#
# [5570 rows x 2 columns]

# %% [markdown]
# #### Juntando as tabelas - Merge

# %%
dados_municipios = pib_municipios.merge(pop_municipios, on = 'City')

dados_municipios
# Out:
#                             City        pib      pop
# 0     Alta Floresta D'Oeste (RO)     734469    21494
# 1                 Ariquemes (RO)    3209761    96833
# 2                    Cabixi (RO)     238412     5351
# 3                    Cacoal (RO)    2792383    86887
# 4                Cerejeiras (RO)     743037    15890
# ...                          ...        ...      ...
# 5565             Vianópolis (GO)     857968    14956
# 5566         Vicentinópolis (GO)     480173     8768
# 5567               Vila Boa (GO)     179899     4215
# 5568          Vila Propício (GO)     308013     5815
# 5569               Brasília (DF)  286943782  2817381
#
# [5570 rows x 3 columns]

# %% [markdown]
# #### Calcular o pib per capita

# %%
dados_municipios['pib_per_capita'] = dados_municipios['pib'] / dados_municipios['pop']

dados_municipios
# Out:
#                             City        pib      pop  pib_per_capita
# 0     Alta Floresta D'Oeste (RO)     734469    21494       34.170885
# 1                 Ariquemes (RO)    3209761    96833       33.147388
# 2                    Cabixi (RO)     238412     5351       44.554663
# 3                    Cacoal (RO)    2792383    86887       32.138099
# 4                Cerejeiras (RO)     743037    15890       46.761296
# ...                          ...        ...      ...             ...
# 5565             Vianópolis (GO)     857968    14956       57.366141
# 5566         Vicentinópolis (GO)     480173     8768       54.764256
# 5567               Vila Boa (GO)     179899     4215       42.680664
# 5568          Vila Propício (GO)     308013     5815       52.968702
# 5569               Brasília (DF)  286943782  2817381      101.847703
#
# [5570 rows x 4 columns]

# %% [markdown]
# #### Separando a cidade e estado em novas colunas

# %%
dados_municipios[['City', 'UF']] = dados_municipios['City'].str.split('(', expand = True)

dados_municipios
# Out:
#                         City        pib      pop  pib_per_capita   UF
# 0     Alta Floresta D'Oeste      734469    21494       34.170885  RO)
# 1                 Ariquemes     3209761    96833       33.147388  RO)
# 2                    Cabixi      238412     5351       44.554663  RO)
# 3                    Cacoal     2792383    86887       32.138099  RO)
# 4                Cerejeiras      743037    15890       46.761296  RO)
# ...                      ...        ...      ...             ...  ...
# 5565             Vianópolis      857968    14956       57.366141  GO)
# 5566         Vicentinópolis      480173     8768       54.764256  GO)
# 5567               Vila Boa      179899     4215       42.680664  GO)
# 5568          Vila Propício      308013     5815       52.968702  GO)
# 5569               Brasília   286943782  2817381      101.847703  DF)
#
# [5570 rows x 5 columns]

# %%
dados_municipios['UF'] = dados_municipios['UF'].str.replace(")", "")

dados_municipios
# Out:
#                        City        pib      pop  pib_per_capita  UF
# 0     Alta Floresta D'Oeste     734469    21494       34.170885  RO
# 1                 Ariquemes    3209761    96833       33.147388  RO
# 2                    Cabixi     238412     5351       44.554663  RO
# 3                    Cacoal    2792383    86887       32.138099  RO
# 4                Cerejeiras     743037    15890       46.761296  RO
# ...                     ...        ...      ...             ...  ..
# 5565             Vianópolis     857968    14956       57.366141  GO
# 5566         Vicentinópolis     480173     8768       54.764256  GO
# 5567               Vila Boa     179899     4215       42.680664  GO
# 5568          Vila Propício     308013     5815       52.968702  GO
# 5569               Brasília  286943782  2817381      101.847703  DF
#
# [5570 rows x 5 columns]

# %% [markdown]
# #### Tratando os espaços em branco

# %%
dados_municipios['City'] = dados_municipios['City'].str.strip()
dados_municipios['UF'] = dados_municipios['UF'].str.strip()
planilha_renner['City'] = planilha_renner['City'].str.strip()
planilha_renner['UF'] = planilha_renner['UF'].str.strip()


dados_municipios
# Out:
# C:\Users\home\AppData\Local\Temp\ipykernel_8276\2396402279.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   planilha_renner['City'] = planilha_renner['City'].str.strip()
# C:\Users\home\AppData\Local\Temp\ipykernel_8276\2396402279.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   planilha_renner['UF'] = planilha_renner['UF'].str.strip()
#                        City        pib      pop  pib_per_capita  UF
# 0     Alta Floresta D'Oeste     734469    21494       34.170885  RO
# 1                 Ariquemes    3209761    96833       33.147388  RO
# 2                    Cabixi     238412     5351       44.554663  RO
# 3                    Cacoal    2792383    86887       32.138099  RO
# 4                Cerejeiras     743037    15890       46.761296  RO
# ...                     ...        ...      ...             ...  ..
# 5565             Vianópolis     857968    14956       57.366141  GO
# 5566         Vicentinópolis     480173     8768       54.764256  GO
# 5567               Vila Boa     179899     4215       42.680664  GO
# 5568          Vila Propício     308013     5815       52.968702  GO
# 5569               Brasília  286943782  2817381      101.847703  DF
#
# [5570 rows x 5 columns]

# %% [markdown]
# #### Juntando os dados dos municípios com os da Renner

# %%
dados_lojas_economia = dados_municipios.merge(planilha_renner, on = ['City', 'UF'])

dados_lojas_economia
# Out:
#             City        pib      pop  pib_per_capita  UF Business  \
# 0         Cacoal    2792383    86887       32.138099  RO   Renner
# 1    Porto Velho   20059522   460434       43.566552  RO   Renner
# 2     Rio Branco   10955675   364756       30.035627  AC   Renner
# 3         Manaus  103281436  2063689       50.046996  AM   Renner
# 4         Manaus  103281436  2063689       50.046996  AM   Renner
# ..           ...        ...      ...             ...  ..      ...
# 422     Brasília  286943782  2817381      101.847703  DF   Renner
# 423     Brasília  286943782  2817381      101.847703  DF   Renner
# 424     Brasília  286943782  2817381      101.847703  DF   Renner
# 425     Brasília  286943782  2817381      101.847703  DF   Renner
# 426     Brasília  286943782  2817381      101.847703  DF   Renner
#
#     Opening date Country             State Shopping Mall / Street
# 0     2021-04-05  Brazil          Rondônia          Shopping Mall
# 1     2008-10-30  Brazil          Rondônia          Shopping Mall
# 2     2011-11-08  Brazil              Acre          Shopping Mall
# 3     2014-12-11  Brazil          Amazonas                 Street
# 4     2014-11-28  Brazil          Amazonas          Shopping Mall
# ..           ...     ...               ...                    ...
# 422   2009-06-25  Brazil  Distrito Federal          Shopping Mall
# 423   2007-10-23  Brazil  Distrito Federal          Shopping Mall
# 424   2001-05-08  Brazil  Distrito Federal          Shopping Mall
# 425   2000-11-16  Brazil  Distrito Federal          Shopping Mall
# 426   1999-12-03  Brazil  Distrito Federal          Shopping Mall
#
# [427 rows x 10 columns]

# %% [markdown]
# # Análise exploratória dos dados
#
# ------------------
#
# ## Passo 3: Observar as características atuais das lojas.
#
# ### % em shoppings

# %%
quantidade_lojas = len(dados_lojas_economia)

qtde_por_tipo = dados_lojas_economia.groupby('Shopping Mall / Street')['Shopping Mall / Street'].size()

qtde_por_tipo / quantidade_lojas
# Out:
# Shopping Mall / Street
# Shopping Mall    0.875878
# Street           0.124122
# Name: Shopping Mall / Street, dtype: float64

# %% [markdown]
# ### A Renner abre lojas em cidades com qual perfil de renda e população?
#
# #### Menor e maior cidade com uma Renner

# %%
dados_lojas_economia.sort_values('pop')
# Out:
#           City        pib       pop  pib_per_capita  UF Business Opening date  \
# 353  Garibaldi    2997963     34335       87.315072  RS   Renner   2021-04-15
# 354    Gramado    2658018     40134       66.228584  RS   Renner   2017-09-20
# 389     Torres    1382097     41751       33.103327  RS   Renner   2021-10-23
# 340     Canela    1595255     48946       32.592142  RS   Renner   2023-08-03
# 388    Taquara    1568872     53242       29.466812  RS   Renner   2023-08-31
# ..         ...        ...       ...             ...  ..      ...          ...
# 256  São Paulo  828980608  11451999       72.387415  SP   Renner   2016-10-11
# 257  São Paulo  828980608  11451999       72.387415  SP   Renner   2016-04-28
# 258  São Paulo  828980608  11451999       72.387415  SP   Renner   2015-11-11
# 251  São Paulo  828980608  11451999       72.387415  SP   Renner   2017-11-16
# 272  São Paulo  828980608  11451999       72.387415  SP   Renner   2000-04-18
#
#     Country              State Shopping Mall / Street
# 353  Brazil  Rio Grande do Sul          Shopping Mall
# 354  Brazil  Rio Grande do Sul                 Street
# 389  Brazil  Rio Grande do Sul          Shopping Mall
# 340  Brazil  Rio Grande do Sul                 Street
# 388  Brazil  Rio Grande do Sul                 Street
# ..      ...                ...                    ...
# 256  Brazil          São Paulo          Shopping Mall
# 257  Brazil          São Paulo          Shopping Mall
# 258  Brazil          São Paulo                 Street
# 251  Brazil          São Paulo          Shopping Mall
# 272  Brazil          São Paulo          Shopping Mall
#
# [427 rows x 10 columns]

# %% [markdown]
# #### Cidade mais rica e mais pobre com uma Renner

# %%
dados_lojas_economia.sort_values('pib_per_capita')
# Out:
#                     City       pib     pop  pib_per_capita  UF Business  \
# 416  Valparaíso de Goiás   2964512  198861       14.907458  GO   Renner
# 52            Camaragibe   2229680  147771       15.088752  PE   Renner
# 56              Paulista   5591652  342167       16.341880  PE   Renner
# 55                Olinda   5788250  349976       16.538991  PE   Renner
# 189          Carapicuíba   6854706  386984       17.713151  SP   Renner
# ..                   ...       ...     ...             ...  ..      ...
# 175              Barueri  58027667  316473      183.357402  SP   Renner
# 176              Barueri  58027667  316473      183.357402  SP   Renner
# 18           Parauapebas  49763040  267836      185.796682  PA   Renner
# 181              Cajamar  22713160   92689      245.046985  SP   Renner
# 132               Maricá  85814296  197277      434.993922  RJ   Renner
#
#     Opening date Country           State Shopping Mall / Street
# 416   2015-11-27  Brazil           Goiás          Shopping Mall
# 52    2018-05-02  Brazil      Pernambuco          Shopping Mall
# 56    2016-04-26  Brazil      Pernambuco          Shopping Mall
# 55    2018-05-08  Brazil      Pernambuco          Shopping Mall
# 189   2016-10-27  Brazil       São Paulo          Shopping Mall
# ..           ...     ...             ...                    ...
# 175   2011-11-30  Brazil       São Paulo          Shopping Mall
# 176   2011-04-28  Brazil       São Paulo          Shopping Mall
# 18    2017-03-23  Brazil            Pará          Shopping Mall
# 181   2023-08-09  Brazil       São Paulo          Shopping Mall
# 132   2021-05-04  Brazil  Rio de Janeiro          Shopping Mall
#
# [427 rows x 10 columns]

# %% [markdown]
# ### Em relação as cidades brasileiras, como é a distribuição de lojas abertas pela Renner em relação ao pib per capta? Ela foge de cidades "pobres"?
# <br>
# Pra visualizar esses dados, vamos igualar o perfil da amostra e retirar outliers.

# %%
#cidades muito ricas deixam o gráfico distorcido
dados_municipios_histograma = dados_municipios[dados_municipios['pib_per_capita'] < 100]
 
#vamos olhar só pra munícipios que suportam uma Renner e deixar só os passíveis de uma abertura
dados_municipios_histograma = dados_municipios_histograma[dados_municipios_histograma['pop'] > 30000]

#vamos tirar as cidades ricas da nossa amostra de lojas também
dados_lojas_e_economicos_histograma = dados_lojas_economia[dados_lojas_economia['pib_per_capita'] < 100]

# %% [markdown]
# Agora podemos visualizar nosso gráfico.

# %%
fig, ax = plt.subplots(figsize = (10,7))

ax.hist(dados_municipios_histograma['pib_per_capita'], bins=50)
ax.hist(dados_lojas_e_economicos_histograma['pib_per_capita'], bins=50)
plt.xlabel('PIB - Per Capita', fontsize = 15)
plt.ylabel('Número de lojas ou municípios', fontsize = 15)
ax.tick_params(axis='both', labelsize = 15)
plt.title("Distribuição de Lojas Renner X \n Distribuição de Municípios no Brasil" , fontsize = 15)
ax.grid(False)

plt.show()
